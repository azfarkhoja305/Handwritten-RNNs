# %% [markdown]
# <a href="https://colab.research.google.com/github/azfarkhoja305/Handwritten-RNNs/blob/master/results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/azfarkhoja305/Handwritten-RNNs.git

# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0,'./Handwritten-RNNs/Handwritten-RNNs')

from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from models.dummy import generate_unconditionally, generate_conditionally, recognize_stroke

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke)

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print(text)
# Out:
# welcome to lyrebird
